# %% [markdown]
# <a href="https://colab.research.google.com/github/VAISHNAVI-ACHI/23CSBTB29/blob/main/PDTC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Decision Tree Classifier Building in Scikit-learn

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %% [markdown]
# Loading Data

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
# load dataset
pima = pd.read_csv("diabetes.csv", header=None, names=col_names)

# %%
pima.head()
# Out:
#       pregnant  glucose             bp           skin  insulin   bmi  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#                    pedigree  age    label
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0

# %% [markdown]
# Feature Selection

# %%
#split dataset in features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = pima[feature_cols] # Features
y = pima.label # Target variable

# %% [markdown]
# Splitting Data

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %% [markdown]
# Building Decision Tree Model

# %%
#split dataset in features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
# The issue is likely caused by including the header row in the data
# Assuming 'pima' is a pandas DataFrame, we need to skip the header row if present
X = pima[feature_cols] # Features
# If 'label' is the name of the target column, this should work
y = pima['label'] # Target variable # make sure 'label' is the correct name for the target column

# %% [markdown]
# Evaluating the Model

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression # Example model
from sklearn import metrics

# ... (Your existing code to load and prepare data) ...

# Split dataset into training

# %%
Accuracy: 0.6753246753246753

# %% [markdown]
# Visualizing Decision Trees

# %%
# Instead of:
# from sklearn.externals.six import StringIO
# Use:
from io import StringIO
from sklearn.tree import export_graphviz
from IPython.display import Image
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('diabetes.png')
Image(graph.create_png())

# %% [markdown]
# Optimizing Decision Tree Performance

# %%
import pandas as pd # Make sure pandas is imported

# Assuming your data is in a CSV file named 'diabetes.csv'
df = pd.read_csv('diabetes.csv')  # Load the data into a DataFrame named 'df'
import pandas as pd # Make sure pandas is imported

# Assuming your data is in a CSV file named 'diabetes.csv'
df = pd.read_csv('diabetes.csv')  # Load the data into a DataFrame named 'df'

# Assuming 'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age' are the correct feature columns
feature_cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']

# %%
Accuracy: 0.7705627705627706
